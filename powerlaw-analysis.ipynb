# %% [markdown]
# # Analysing the powerlaw parameters

# %% [markdown]
# The slope $\alpha$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("results/powerlaw_parameters.csv")

# %%
data.head()

# %% [markdown]
# Create new dataframe with only x,y axis and values for the heatmap, then find max and min values.

# %%
df = data[['llos', 'ltrans', 'alpha']]

# %%
df.head()
print(df.alpha.max(), df.alpha.min())
# Out:
# 1.8787473892742723 1.2720978992212597

# %% [markdown]
# Create pivot table as basis for the heatmap

# %%
piv = pd.pivot_table(df, values="alpha",index=["ltrans"], columns=["llos"], fill_value=0)
piv.head()
# Out:
# llos         200       210       220       230       240       250       260  \
# ltrans
# 0.1     1.340299  1.334679  1.331507  1.329130  1.327206  1.322440  1.318082
# 0.2     1.484649  1.346701  1.499910  1.354204  1.382238  1.390841  1.385164
# 0.3     1.446196  1.489401  1.518296  1.507560  1.499940  1.505050  1.510033
# 0.4     1.273899  1.404418  1.295495  1.383395  1.403314  1.395486  1.405010
# 0.5     1.424533  1.407038  1.443048  1.468027  1.465700  1.477789  1.461324
#
# llos         270       280       290  ...       710       720       730  \
# ltrans                                ...
# 0.1     1.339404  1.338900  1.335543  ...  1.315935  1.315532  1.315425
# 0.2     1.367770  1.364773  1.387911  ...  1.272098  1.327122  1.304411
# 0.3     1.518689  1.512465  1.385608  ...  1.415942  1.399110  1.397336
# 0.4     1.366169  1.378510  1.406807  ...  1.438172  1.436399  1.465880
# 0.5     1.490353  1.484720  1.489149  ...  1.328186  1.325211  1.324534
#
# llos         740       750       760       770       780       790       800
# ltrans
# 0.1     1.314961  1.314701  1.311864  1.311775  1.311446  1.311373  1.311256
# 0.2     1.304067  1.303767  1.304249  1.303832  1.302624  1.301527  1.301469
# 0.3     1.429333  1.428532  1.411058  1.410284  1.393596  1.409399  1.393971
# 0.4     1.312374  1.587160  1.385727  1.385466  1.382139  1.381505  1.323415
# 0.5     1.362201  1.319310  1.320356  1.319828  1.319237  1.362112  1.384645
#
# [5 rows x 61 columns]

# %% [markdown]
# Sort the ltrans rows in descending order for nicer heatmap

# %%
result = piv.sort_values(('ltrans'), ascending=False)
result.head()
# Out:
# llos         200       210       220       230       240       250       260  \
# ltrans
# 2.0     1.343457  1.354855  1.379331  1.316572  1.339194  1.356816  1.338643
# 1.9     1.323529  1.326781  1.325253  1.328362  1.312436  1.314530  1.506258
# 1.8     1.337293  1.379549  1.328416  1.332941  1.314287  1.370020  1.338005
# 1.7     1.328876  1.405858  1.332705  1.665145  1.332646  1.705716  1.326613
# 1.6     1.312661  1.335565  1.329901  1.347865  1.341333  1.328489  1.398664
#
# llos         270       280       290  ...       710       720       730  \
# ltrans                                ...
# 2.0     1.429304  1.395606  1.421358  ...  1.372393  1.548475  1.456638
# 1.9     1.677491  1.623751  1.392579  ...  1.406489  1.397300  1.411015
# 1.8     1.649046  1.589468  1.332658  ...  1.598242  1.383737  1.383399
# 1.7     1.350843  1.351493  1.575503  ...  1.374604  1.372568  1.392448
# 1.6     1.339849  1.332797  1.363031  ...  1.406607  1.395086  1.390926
#
# llos         740       750       760       770       780       790       800
# ltrans
# 2.0     1.410614  1.375728  1.409788  1.378603  1.387060  1.499162  1.451423
# 1.9     1.392117  1.394918  1.385812  1.383085  1.411836  1.383081  1.374251
# 1.8     1.381090  1.418132  1.376617  1.376091  1.416046  1.362542  1.411313
# 1.7     1.381417  1.379767  1.487492  1.395344  1.440782  1.403003  1.373434
# 1.6     1.409855  1.404032  1.394818  1.391715  1.403014  1.392913  1.389108
#
# [5 rows x 61 columns]

# %%
ax = sns.heatmap(result, vmin=1.1, vmax=1.9, annot=True, linewidths=.5, cmap="Blues")
ax.set_title("Powerlaw parameter alpha for different line-of-sight\n and transverse values")
plt.setp(ax.xaxis.get_majorticklabels(), rotation=90)
plt.yticks(rotation=0)
plt.rcParams['figure.figsize'] = (14,8)
plt.rcParams['figure.dpi'] = 200
plt.tight_layout()
plt.savefig('seabornPandas1.png', dpi=400, facecolor="w")
plt.show()

# %%
ax = sns.heatmap(result, vmin=1.1, vmax=1.9, cmap="Blues")
ax.set_title("Powerlaw parameter alpha for different line-of-sight\n and transverse values")
plt.setp(ax.xaxis.get_majorticklabels(), rotation=90)
plt.yticks(rotation=0)
plt.rcParams['figure.figsize'] = (14,8)
plt.rcParams['figure.dpi'] = 200
plt.tight_layout()
plt.savefig('seabornPandas.png', dpi=400, facecolor="w")
plt.show()
